# %%
 # !pip install git+https://github.com/openai/whisper.git #install whisper getting from github
 # !sudo apt update && sudo apt install ffmpeg #ffmpeg allows us to work with audio and video files
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-8k0y4pul
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-8k0y4pul
#   Resolved https://github.com/openai/whisper.git to commit e8622f9afc4eba139bf796c210f5c01081000472
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 21.3 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798395 sha256=b30178aa95038cd01e02c98f9eecf1af27e65c3ef96b7a8a63731d6ae36fe367
#   Stored in directory: /tmp/pip-ephem-wheel-cache-en664r8n/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# ...

# %%
pip install pytube
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from pytube import YouTube

def download_youtube_audio(video_url):
    yt = YouTube(video_url)
    stream = yt.streams.filter(only_audio=True).first()
    audio_file_path = yt.title + ".mp3"  # Output audio file path

    stream.download(filename=audio_file_path)

    return audio_file_path

# Main code flow
video_url = "https://www.youtube.com/watch?v=vWh1AJwAIg0"
audio_file_path = download_youtube_audio(video_url)

# %% [markdown]
# You can choose 5 different model:
#
#
# *   Tiny
# *   Base
# *   Small
# *   Medium
# *   Large

# %%
 # run whisper asr
 # !whisper "/content/Pharmacology - IMMUNOSUPPRESSANTS (MADE EASY).mp3" --model medium.en
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:14<00:00, 104MiB/s]
# [00:00.000 --> 00:08.100]  In this lecture we are gonna cover the pharmacology of immunosuppressants, so let's get right
# [00:08.100 --> 00:09.400]  into it.
# [00:09.400 --> 00:14.000]  The immune system is a complex network of cells and proteins that work together to defend
# [00:14.000 --> 00:18.720]  the body against substances it sees as harmful or foreign.
# [00:18.720 --> 00:23.840]  Now the human immune system has two levels of immunity, innate and adaptive.
# [00:23.840 --> 00:29.500]  The innate immunity is nonspecific and fast-acting, and serves as the primary line of protection
# [00:29.500 --> 00:31.980]  against pathogen invasion.
# [00:31.980 --> 00:36.620]  Numerous cells are involved in the innate immune response, including natural killer
# [00:36.620 --> 00:42.580]  cells, mast cells and granulocytes, as well as the phagocytic cells such as macrophages,
# ...

# %% [markdown]
# you should see an SRT file, a TXT file and a VTT file. A text file is just all of the text from the audio. SRT and VTT these are caption formats that also include timestamps

# %%
 #additional arguments
 # !whisper -h
# Out:
# usage: whisper
#        [-h]
#        [--model {tiny.en,tiny,base.en,base,small.en,small,medium.en,medium,large-v1,large-v2,large}]
#        [--model_dir MODEL_DIR]
#        [--device DEVICE]
#        [--output_dir OUTPUT_DIR]
#        [--output_format {txt,vtt,srt,tsv,json,all}]
#        [--verbose VERBOSE]
#        [--task {transcribe,translate}]
# ...
